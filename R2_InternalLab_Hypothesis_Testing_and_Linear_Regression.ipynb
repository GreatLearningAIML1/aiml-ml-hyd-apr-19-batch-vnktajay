# %% [markdown]
# ## Lab 2

# %% [markdown]
# Welcome to the second lab of the AIML!
# In addition to implementing code, there will be questions that you must answer which relate to the lab and your implementation. Each question you will answer is preceded by a **'Question X'** header. Carefully read each question and provide you answer or code in the following textboxes with **'Answer:'** header. Your lab submission will be evaluated based on your answers to each of the questions and the implementation you provide.

# %% [markdown]
# # Every question is of 1 mark.

# %% [markdown]
# ## Overview

# %% [markdown]
# This module covers,
#
# 1) One sample and Two sample t-tests
#
# 2) ANOVA
#
# 3) Type I and Type II errors
#
# 4) Probabilty Distributions
#
# 5) Linear Regression

# %% [markdown]
# ## Hypothesis Testing

# %% [markdown]
# The purpose of the test is to tell if there is any significant difference between two data sets.

# %% [markdown]
# ## Question 1
#
# *A student is trying to decide between two GPUs. He want to use the GPU for his research to run Deep learning algorithms, so the only thing he is concerned with is speed.*
#
# *He picks a Deep Learning algorithm on a large data set and runs it on both GPUs 15 times, timing each run in hours. Results are given in the below lists GPU1 and GPU2.*

# %% [markdown]
# Hint: You can import ttest function from scipy to perform t tests

# %% [markdown]
# Given,
#
# Null Hypothesis : There is no significant difference between data sets
#
# Alternate Hypothesis : There is a significant difference
#
# *Do two-sample testing and check whether to reject Null Hypothesis or not.*
#
# #### Answer:

# %%
import pandas as pd
GPU1 = pd.DataFrame([11,9,10,11,10,12,9,11,12,9,11,12,9,10,9])
GPU2 = pd.DataFrame([11,13,10,13,12,9,11,12,12,11,12,12,10,11,13])

# %%
import numpy as np
import scipy.stats as stats
from scipy.stats import ttest_1samp, ttest_ind, mannwhitneyu, levene, shapiro
from statsmodels.stats.power import ttest_power
t_statistic, p_value = ttest_ind(GPU1, GPU2)
print(t_statistic, p_value)

if p_value < 0.05:    # alpha value is 0.05 or 5%
   print(" we are rejecting null hypothesis")
else:
  print("we are accepting null hypothesis")
#As p-value is less than 0.05 we are rejecting the null hypothesis.
# Out:
# [-2.62762951] [0.01379428]
#  we are rejecting null hypothesis

# %% [markdown]
# [## Question 2
# ](https://)
# He is trying a third GPU which is GPU3.

# %%
GPU3 = pd.DataFrame([9,10,9,11,10,13,12,9,12,12,13,12,13,10,11])

#Assumption: Both the datasets (GPU1 & GPU 3) are random, independent, parametric & normally distributed

# %% [markdown]
# *Do two-sample testing and check whether there is significant differene between speeds of two GPUs GPU1 and GPU3.*
#
# #### Answer:

# %%
t_statistic, p_value = ttest_ind(GPU1, GPU3)
print(t_statistic, p_value)
# Out:
# [-1.49889438] [0.14509211]
# we are accepting null hypothesis

# %%
if p_value < 0.05:    # alpha value is 0.05 or 5%
   print(" we are rejecting null hypothesis")
else:
  print("we are accepting null hypothesis")
#As p-value is less than 0.05 we are rejecting the null hypothesis.
# Out:
# we are accepting null hypothesis

# %% [markdown]
# ### ANOVA

# %% [markdown]
# ## Question 3
#
# If you need to compare more than two data sets at a time, an ANOVA is your best bet.
#
# *The results from three experiments with overlapping 95% confidence intervals are given below, and we want to confirm that the results for all three experiments are not significantly different.*
#
# #Assumption: All the 3 datasets (e1,e2 & e3) are random, independent, parametric & normally distributed
# But before conducting ANOVA, test equality of variances (using Levene's test) is satisfied or not. If not, then mention that we cannot depend on the result of ANOVA

# %%
import pandas as pd
e1 = pd.DataFrame([1.595440,1.419730,0.000000,0.000000])
e2 = pd.DataFrame([1.433800,2.079700,0.892139,2.384740])
e3 = pd.DataFrame([0.036930,0.938018,0.995956,1.006970])

# %% [markdown]
# Hint - You can use stats.levene function and stats.f_oneway function.

# %% [markdown]
# #### Answer:

# %%
# Levene variance test for Control and Treatment groups 

LeveneResult = stats.levene(e1, e2, e3)
print(LeveneResult)

if LeveneResult.pvalue > 0.05:    # alpha value is 0.05 or 5%
   print("The variance criterion holds true")
else:
  print("The variance criterion doesn't holds true")
 
F_onewayResult=stats.f_oneway(e1, e2, e3)
print(F_onewayResult) 

if LeveneResult.pvalue > 0.05:    # alpha value is 0.05 or 5%
   print("interaction effect is there between groups")
else:
  print("interaction effect is not present between groups")
# Out:
# LeveneResult(statistic=array([2.67417257]), pvalue=array([0.12259793]))
# The variance criterion holds true
# F_onewayResult(statistic=array([2.51357623]), pvalue=array([0.13574645]))
# interaction effect is there between groups

# %% [markdown]
# ## Question 4
#
# *In one or two sentences explain about **TypeI** and **TypeII** errors.*
#
# #### Answer:

# %%
print("A type I error (or error of the first kind) is the incorrect rejection of a true null hypothesis. Usually a type I error leads one to conclude that a supposed effect or relationship exists when in fact it doesn't. Examples of type I errors include a test that shows a patient to have a disease when in fact the patient does not have the disease, a fire alarm going on indicating a fire when in fact there is no fire, or an experiment indicating that a medical treatment should cure a disease when in fact it does not.")
# Out:
# A type I error (or error of the first kind) is the incorrect rejection of a true null hypothesis. Usually a type I error leads one to conclude that a supposed effect or relationship exists when in fact it doesn't. Examples of type I errors include a test that shows a patient to have a disease when in fact the patient does not have the disease, a fire alarm going on indicating a fire when in fact there is no fire, or an experiment indicating that a medical treatment should cure a disease when in fact it does not.

# %%
print("#A type II error (or error of the second kind) is the failure to reject a false null hypothesis. Examples of type II errors would be a blood test failing to detect the disease it was designed to detect, in a patient who really has the disease; a fire breaking out and the fire alarm does not ring; or a clinical trial of a medical treatment failing to show that the treatment works when really it does.")
# Out:
# #A type II error (or error of the second kind) is the failure to reject a false null hypothesis. Examples of type II errors would be a blood test failing to detect the disease it was designed to detect, in a patient who really has the disease; a fire breaking out and the fire alarm does not ring; or a clinical trial of a medical treatment failing to show that the treatment works when really it does.

# %% [markdown]
# # Question 5
# You are a manager of a chinese restaurant. You want to determine whether the waiting time to place an order has changed in the past month from its previous population mean value of 4.5 minutes.
# State the null and alternative hypothesis.

# %%
NULL HYPOTHESIS : The waiting time for an order is not 4.5 minutes per order

# %%
ALTERNATE HYPOTHESIS : The waiting time for an order is 4.5 minutes per order

# %% [markdown]
# # Question 6
# Get the binomial distribution with n = 10, p = .7 and k = [0, 1, 2, 3, 4, 5, 6, 7]
#
# Hint - Use stats.binom.pmf() function for this.

# %%
from scipy.stats import binom
n = 10
p = 0.7
k = np.arange(0,7)
binomial = binom.pmf(k,n,p)
print(binomial)
# Out:
# [5.90490000e-06 1.37781000e-04 1.44670050e-03 9.00169200e-03
#  3.67569090e-02 1.02919345e-01 2.00120949e-01]

# %% [markdown]
# # Question 7
# Plot the distribution created in the above question.

# %%
import pylab, scipy, scipy.stats
x = scipy.linspace(0,10,11)
pmf = scipy.stats.binom.pmf(x,10,0.7)
pylab.plot(x,pmf)

# %% [markdown]
# # Linear Regression

# %% [markdown]
# # Simple Linear Regression

# %% [markdown]
# Here we will try to see that if we can make a regression model to predict one column of a dataset by the use of other coloumn.
#
# ## Dataset
#
# Population of U.S. Cities
#
# ### Description
# The bigcity data frame has 49 rows and 2 columns.
#
# The measurements are the population (in 1000's) of 49 U.S. cities in 1920 and 1930. The 49 cities are a random sample taken from the 196 largest cities in 1920.
#
# ### Format
# This data frame contains the following columns:
#
# `u`
# The 1920 population.
#
# `x`
# The 1930 population.
#
# There is one unnamed column also in this dataset. Please remove and ignore that coloumn.
#
# Source
#
# The data were obtained from
#
# Cochran, W.G. (1977) Sampling Techniques. Third edition. John Wiley
#
# References
#
# Davison, A.C. and Hinkley, D.V. (1997) Bootstrap Methods and Their Application. Cambridge University Press.

# %% [markdown]
# # Question 8
# Read the dataset given in file named 'bigcity.csv'.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt   #Data visualisation libraries 
import seaborn as sns
# %matplotlib inline

bigcity = pd.read_csv('bigcity.csv')

# %% [markdown]
# # Question 9 - Transform the dataset
# Find the number of rows in given dataset and separate the input(u column)  and target variables(x column) into X and Y.
#
# Remove the unnamed coloumn.
#
# Hint: You can shape function to get the size of the dataframe

# %%
bigcity.shape
# Out:
# (49, 3)

# %%
bigcity.columns
# Out:
# Index(['Unnamed: 0', 'u', 'x'], dtype='object')

# %%
bigcity.drop(columns = 'Unnamed: 0', inplace=True)

# %% [markdown]
# ## Question 10 - Check the dataset for any missing values and also print out the correlation matrix

# %%
bigcity.isna()
# Out:
#         u      x
# 0   False  False
# 1   False  False
# 2   False  False
# 3   False  False
# 4   False  False
# 5   False  False
# 6   False  False
# 7   False  False
# 8   False  False
# 9   False  False
# 10  False  False
# 11  False  False
# 12  False  False
# 13  False  False
# 14  False  False
# 15  False  False
# 16  False  False
# 17  False  False
# 18  False  False
# 19  False  False
# 20  False  False
# 21  False  False
# 22  False  False
# 23  False  False
# 24  False  False
# 25  False  False
# 26  False  False
# 27  False  False
# 28  False  False
# 29  False  False
# 30  False  False
# 31  False  False
# 32  False  False
# 33  False  False
# 34  False  False
# 35  False  False
# 36  False  False
# 37  False  False
# 38  False  False
# 39  False  False
# 40  False  False
# 41  False  False
# 42  False  False
# 43  False  False
# 44  False  False
# 45  False  False
# 46  False  False
# 47  False  False
# 48  False  False

# %% [markdown]
# You can use .isna() and .corr() functions to check NA's and correlation in the dataframe respectively

# %%
bigcity.corr()
# Out:
#           u         x
# u  1.000000  0.981742
# x  0.981742  1.000000

# %% [markdown]
# ### The high correlation betwwen u and x indicates that the variable u is a good predictor of variable x

# %% [markdown]
# # Question 11 - Split data into train, test sets
# Divide the data into training and test sets with 80-20 split using scikit-learn. Print the shapes of training and test feature sets.*

# %% [markdown]
# Check: train_test_split function

# %%
from sklearn.model_selection import train_test_split
X=np.array(bigcity.iloc[:,:1])
Y=np.array(bigcity.iloc[:,1:2])
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2)
print(X_train.shape,X_test.shape,Y_train.shape,Y_test.shape)
# Out:
# (39, 1) (10, 1) (39, 1) (10, 1)

# %% [markdown]
# # Question 12 - Find coefficients & intercept
# Estimate the coefficients b0 and b1 using scikit-learn.

# %%
from sklearn import linear_model
reg=linear_model.LinearRegression()
reg.fit(X_train,Y_train)
b0=reg.intercept_
b1=reg.coef_
#AS per equuation y=b0+b1*x
print("b0 = {}".format(b0))
print("b1 = {}".format(b1))
# Out:
# b0 = [6.42372069]
# b1 = [[1.16072951]]

# %% [markdown]
# Check: coef_ and intercept_ functions can help you get coefficients & intercept

# %% [markdown]
# # Question 13 - Linear Relationship between feature and target
# Plot the line with b1 and b0 as slope and y-intercept.
#
# Hint - y = mx + c, plot y

# %% [markdown]
# # Question 14 - Evaluation of model with scikit-learn
# Validate the model with Root Mean Squares error and R^2 score using scikit-learn. RMSE and R2 for test data and prediction

# %% [markdown]
# Hint: You can import mean_squared_error function & r2 (R square) from sklearn.metrics. Performing root operation over mean square error over mean square error gives you root mean square error

# %%
#y_pred = lm.predict(X_test)

from sklearn.metrics import mean_squared_error, r2_score
from math import sqrt

mse = mean_squared_error(Y_test, y_pred)

rmse = sqrt(mse)

# %% [markdown]
# ## Question 15 - Calculate the accuracy of the model for both training and test data set

# %% [markdown]
# ### Hint: .score() function
